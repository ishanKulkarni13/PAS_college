# %% [markdown]
# <a href="https://colab.research.google.com/github/ishanKulkarni13/PAS_college/blob/main/tut-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My Info:
# - Name: Ishan Kulkarni
# - Roll no: 32
# - PRN: 1251080001

# %% [markdown]
# View on Google Collab:
# [Open the Google Colab Notebook](https://colab.research.google.com/github/ishanKulkarni13/PAS_college/blob/main/tut-1.ipynb)

# %%
print("test if the gc syncs well")
# Out:
# test if the gc syncs well

# %%
print("It isss!!!")
# Out:
# It isss!!!
