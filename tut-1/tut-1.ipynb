# %% [markdown]
# <a href="https://colab.research.google.com/github/ishanKulkarni13/PAS_college/blob/main/tut-1/tut-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My Info:
# - Name: Ishan Kulkarni
# - Roll no: 32
# - PRN: 1251080001

# %% [markdown]
# # Open this on your prefered platform
#
# View on Google Collab:
# [Open the Google Colab Notebook](https://colab.research.google.com/github/ishanKulkarni13/PAS_college)
#
# Select the tut-1.ipynb :)
#
# ---
#
# View on github:
# [View tut-1.ipynb on GitHub](https://github.com/ishanKulkarni13/PAS_college/)

# %%
import os
print(os.listdir())
# Out:
# ['.gitignore', '.ipynb_checkpoints', '.venv', 'data', 'tut-1.ipynb']

# %%
import pandas as pd
import numpy as np
import time
from tabulate import tabulate


print("Probability and Statistics - Tutorial 1")


# Manual Functions

def mean(A):
    total = 0

    for x in A:
        total += x

    return total / len(A)


def median(A):
    n = len(A)

    if n % 2 == 1:
        return A[n // 2]

    return (A[n // 2 - 1] + A[n // 2]) / 2

def mode(A):
    mode = A[0]
    max_count = 0

    for i in range(len(A)):
        count = 0

        for j in range(len(A)):
            if A[i] == A[j]:
                count += 1

        if count > max_count:
            max_count = count
            mode = A[i]

    return mode

def variance(A):
    m = mean(A)

    total = 0

    for x in A:
        total += (x - m) ** 2

    return total / len(A)


def std_dev(A):
    return variance(A) ** 0.5


def quartiles(A):
    n = len(A)

    if n % 2 == 0:
        lower = A[:n // 2]
        upper = A[n // 2:]
    else:
        lower = A[:n // 2]
        upper = A[n // 2 + 1:]

    q0 = A[0]
    q1 = median(lower)
    q2 = median(A)
    q3 = median(upper)
    q4 = A[-1]

    return q0, q1, q2, q3, q4


def range_value(A):
    maximum = A[0]
    minimum = A[0]

    for x in A:

        if x > maximum:
            maximum = x

        if x < minimum:
            minimum = x

    return maximum - minimum


  
# Read Dataset
  

dataset = pd.read_csv("./data/test.csv")

dataset = dataset.dropna()

subjects = ["Sub1", "Sub2", "Sub3", "Sub4"]


  
# Store Results
  

results = {}

statistics = [
    "Count",
    "Mean",
    "Median",
    "Mode",
    "Variance",
    "Std Dev",
    "Q0",
    "Q1",
    "Q2",
    "Q3",
    "Q4",
    "IQR",
    "Range"
]


# Time for each statistic
manual_times = [0.0] * len(statistics)
numpy_times = [0.0] * len(statistics)


  
# Process Each Subject
  

for subject in subjects:

    A = dataset[subject].astype(float).tolist()

    A.sort()


     
    # Manual Mean
     

    start = time.perf_counter()

    manual_mean = mean(A)

    manual_times[1] += (time.perf_counter() - start) * 1000


     
    # Manual Median
     

    start = time.perf_counter()

    manual_median = median(A)

    manual_times[2] += (time.perf_counter() - start) * 1000


     
    # Manual Mode
     

    start = time.perf_counter()

    manual_mode = mode(A)

    manual_times[3] += (time.perf_counter() - start) * 1000


    # Manual Variance

    start = time.perf_counter()

    manual_variance = variance(A)

    manual_times[4] += (time.perf_counter() - start) * 1000


    # Manual Standard Deviation

    start = time.perf_counter()

    manual_std = manual_variance ** 0.5

    manual_times[5] += (time.perf_counter() - start) * 1000


    # Manual Quartiles

    start = time.perf_counter()

    q0, q1, q2, q3, q4 = quartiles(A)

    quartile_time = (time.perf_counter() - start) * 1000


    # Store quartile time for Q1, Q2 and Q3
    manual_times[7] += quartile_time / 3
    manual_times[8] += quartile_time / 3
    manual_times[9] += quartile_time / 3


    # Q0 and Q4 are just first and last elements
    start = time.perf_counter()

    manual_q0 = A[0]

    manual_times[6] += (time.perf_counter() - start) * 1000


    start = time.perf_counter()

    manual_q4 = A[-1]

    manual_times[10] += (time.perf_counter() - start) * 1000


    # Manual IQR

    start = time.perf_counter()

    manual_iqr = q3 - q1

    manual_times[11] += (time.perf_counter() - start) * 1000


    # Manual Range

    start = time.perf_counter()

    manual_range = range_value(A)

    manual_times[12] += (time.perf_counter() - start) * 1000



    # Mean
    start = time.perf_counter()

    np_mean = np.mean(A)

    numpy_times[1] += (time.perf_counter() - start) * 1000


    # Median
    start = time.perf_counter()

    np_median = np.median(A)

    numpy_times[2] += (time.perf_counter() - start) * 1000


    # Mode
    start = time.perf_counter()

    np_mode = pd.Series(A).mode().iloc[0]

    numpy_times[3] += (time.perf_counter() - start) * 1000


    # Variance
    start = time.perf_counter()

    np_variance = np.var(A)

    numpy_times[4] += (time.perf_counter() - start) * 1000


    # Standard Deviation
    start = time.perf_counter()

    np_std = np.std(A)

    numpy_times[5] += (time.perf_counter() - start) * 1000


    # Q0
    start = time.perf_counter()

    np_q0 = np.min(A)

    numpy_times[6] += (time.perf_counter() - start) * 1000


    # Q1
    start = time.perf_counter()

    np_q1 = np.percentile(A, 25)

    numpy_times[7] += (time.perf_counter() - start) * 1000


    # Q2
    start = time.perf_counter()

    np_q2 = np.percentile(A, 50)

    numpy_times[8] += (time.perf_counter() - start) * 1000


    # Q3
    start = time.perf_counter()

    np_q3 = np.percentile(A, 75)

    numpy_times[9] += (time.perf_counter() - start) * 1000


    # Q4
    start = time.perf_counter()

    np_q4 = np.max(A)

    numpy_times[10] += (time.perf_counter() - start) * 1000


    # IQR
    start = time.perf_counter()

    np_iqr = np_q3 - np_q1

    numpy_times[11] += (time.perf_counter() - start) * 1000


    # Range
    start = time.perf_counter()

    np_range = np.max(A) - np.min(A)

    numpy_times[12] += (time.perf_counter() - start) * 1000


    # Store manual results

    results[subject] = [
        len(A),
        manual_mean,
        manual_median,
        manual_mode,
        manual_variance,
        manual_std,
        manual_q0,
        q1,
        q2,
        q3,
        manual_q4,
        manual_iqr,
        manual_range
    ]


# Create final table

table = []

for i in range(len(statistics)):

    row = [
        statistics[i],
        results["Sub1"][i],
        results["Sub2"][i],
        results["Sub3"][i],
        results["Sub4"][i]
    ]

    if i == 0:
        row.append("-")
        row.append("-")
    else:
        row.append(manual_times[i])
        row.append(numpy_times[i])

    table.append(row)


# Display table

print()

print(
    tabulate(
        table,
        headers=[
            "Statistic",
            "Sub1",
            "Sub2",
            "Sub3",
            "Sub4",
            "Total Manual Time (ms)",
            "Total NumPy Time (ms)"
        ],
        tablefmt="grid",
        floatfmt=".4f"
    )
)
# Out:
# Probability and Statistics - Tutorial 1
#
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Statistic   |       Sub1 |       Sub2 |       Sub3 |       Sub4 | Total Manual Time (ms)   | Total NumPy Time (ms)   |
# +=============+============+============+============+============+==========================+=========================+
# | Count       | 21137.0000 | 21137.0000 | 21137.0000 | 21137.0000 | -                        | -                       |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Mean        |    69.6205 |    69.4449 |    69.6050 |    69.3273 | 1.6968999989330769       | 2.833999998983927       |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Median      |    70.0000 |    69.0000 |    70.0000 |    69.0000 | 0.008699997124494985     | 3.0411000007006805      |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Mode        |    60.0000 |    45.0000 |    75.0000 |    67.0000 | 52901.847299999645       | 5.6669000077818055      |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Variance    |   208.9294 |   209.3219 |   208.8814 |   208.7090 | 7.586200004880084        | 2.8512999997474253      |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Std Dev     |    14.4544 |    14.4680 |    14.4527 |    14.4468 | 0.0021999985619913787    | 3.188499998941552       |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Q0          |    45.0000 |    45.0000 |    45.0000 |    45.0000 | 0.0011999945854768157    | 3.096100001130253       |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Q1          |    57.0000 |    57.0000 |    57.0000 |    57.0000 | 0.1281333328127706       | 3.99939999988419        |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Q2          |    70.0000 |    69.0000 |    70.0000 |    69.0000 | 0.1281333328127706       | 3.778799993597204       |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Q3          |    82.0000 |    82.0000 |    82.0000 |    82.0000 | 0.1281333328127706       | 2.967800002807053       |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Q4          |    94.0000 |    94.0000 |    94.0000 |    94.0000 | 0.0012999953469261527    | 2.6165999988734256      |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | IQR         |    25.0000 |    25.0000 |    25.0000 |    25.0000 | 0.0013000026228837669    | 0.004799996531801298    |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
# | Range       |    49.0000 |    49.0000 |    49.0000 |    49.0000 | 2.78670000625425         | 5.263899998681154       |
# +-------------+------------+------------+------------+------------+--------------------------+-------------------------+
#
# Note:
# Manual quartiles use the median-of-halves method.
# NumPy uses percentile interpolation, so Q1, Q3 and IQR
# may have slightly different values.
